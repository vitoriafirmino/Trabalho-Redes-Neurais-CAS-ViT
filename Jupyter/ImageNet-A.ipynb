# %%
# !git clone https://github.com/Tianfang-Zhang/CAS-ViT.git
# %cd CAS-ViT
# Out:
# Cloning into 'CAS-ViT'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 158 (delta 55), reused 150 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (158/158), 5.23 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/CAS-ViT

# %%
# !pip install torch==1.11.0 torchvision==0.12.0
# !pip install timm==0.5.4
# !pip install mmcv-full==1.5.3 -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.8.0/index.html
# !pip install mmdet==2.24.0
# !pip install mmsegmentation==0.24.0

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/CAS-ViT/classification
# Out:
# /content/CAS-ViT/classification

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Com Adapter

# %%
# !python main.py \
  --input_size 224 --batch_size 128 --epochs 150 \
  --model rcvit_xs --data_path "/content/drive/My Drive/ImageNet-A/train" \
  --eval_data_path "/content/drive/My Drive/ImageNet-A/test" \
  --lr 5e-5 --min_lr 5e-5 \
  --weight_decay 0.001 --output_dir "/content/drive/My Drive/ImageNet-A/output" \
  --finetune "model/cas-vit-xs.pth" --warmup_epochs 3 \
  --data_set image_folder \
  --model_ema_eval True --model_ema False --use_amp false
# Out:
# Not using distributed mode
# ...

# %% [markdown]
# Sem Adapter

# %%
# !python main.py \
  --input_size 224 --batch_size 128 --epochs 150 \
  --model rcvit_xs --data_path "/content/drive/My Drive/ImageNet-A/train" \
  --eval_data_path "/content/drive/My Drive/ImageNet-A/test" \
  --lr 5e-5 --min_lr 5e-5 \
  --weight_decay 0.001 --output_dir "/content/drive/My Drive/ImageNet-A/output-semadapter" \
  --finetune "model/cas-vit-xs.pth" --warmup_epochs 3 \
  --data_set image_folder \
  --model_ema_eval True --model_ema False --use_amp false
# Out:
# Not using distributed mode
# ...
